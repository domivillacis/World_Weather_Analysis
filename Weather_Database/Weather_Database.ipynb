# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 749

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather ["weather"][0]["description"]

            
        # Append the city information into the city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | airai
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | ternate
# Processing Record 7 of Set 1 | kahului
# Processing Record 8 of Set 1 | ushibuka
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | tandil
# Processing Record 11 of Set 1 | torrington
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | bulgan
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | provideniya
# Processing Record 17 of Set 1 | medicine hat
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | nioro
# Processing Record 20 of Set 1 | roma
# Processing Record 21 of Set 1 | porto novo
# Processing Record 22 of Set 1 | lagoa
# Processing Record 23 of Set 1 | hvammstangi
# City not found. Skipping...
# Processing Record 24 of Set 1 | farafangana
# Processing Record 25 of Set 1 | turayf
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | fare
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | port hardy
# Processing Record 31 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | winneba
# Processing Record 34 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 35 of Set 1 | ratnagiri
# Processing Record 36 of Set 1 | avera
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | mkushi
# Processing Record 39 of Set 1 | olkhovka
# Processing Record 40 of Set 1 | mamakan
# Processing Record 41 of Set 1 | eldikan
# City not found. Skipping...
# Processing Record 42 of Set 1 | oussouye
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 1 | savannah bight
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | portage
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | talnakh
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | qui nhon
# Processing Record 3 of Set 2 | half moon bay
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | morondava
# Processing Record 6 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | nanortalik
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | saint anthony
# Processing Record 11 of Set 2 | taoudenni
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | broome
# Processing Record 14 of Set 2 | phon
# Processing Record 15 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 16 of Set 2 | mandalgovi
# Processing Record 17 of Set 2 | berezovka
# Processing Record 18 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 2 | alizai
# Processing Record 20 of Set 2 | carutapera
# Processing Record 21 of Set 2 | ponta do sol
# Processing Record 22 of Set 2 | tuktoyaktuk
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | saint-pierre
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | ust-barguzin
# Processing Record 28 of Set 2 | zhangye
# Processing Record 29 of Set 2 | gornozavodsk
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | ballina
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | athabasca
# Processing Record 36 of Set 2 | george town
# Processing Record 37 of Set 2 | kampot
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | honningsvag
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | ulladulla
# Processing Record 42 of Set 2 | kapaa
# Processing Record 43 of Set 2 | tombouctou
# Processing Record 44 of Set 2 | yurino
# Processing Record 45 of Set 2 | gerash
# Processing Record 46 of Set 2 | port alfred
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | pyapon
# Processing Record 49 of Set 2 | opunake
# Processing Record 50 of Set 2 | ambilobe
# Processing Record 1 of Set 3 | teya
# Processing Record 2 of Set 3 | atuona
# Processing Record 3 of Set 3 | puerto carreno
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | shenjiamen
# Processing Record 7 of Set 3 | hami
# Processing Record 8 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 3 | pacific grove
# Processing Record 10 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | torbay
# Processing Record 13 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 14 of Set 3 | yellowknife
# Processing Record 15 of Set 3 | sarkand
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | nizhniy chir
# Processing Record 18 of Set 3 | carnarvon
# Processing Record 19 of Set 3 | mayumba
# Processing Record 20 of Set 3 | pawayan
# Processing Record 21 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 3 | diu
# Processing Record 23 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 24 of Set 3 | mier
# Processing Record 25 of Set 3 | tefe
# Processing Record 26 of Set 3 | vaini
# Processing Record 27 of Set 3 | kodiak
# Processing Record 28 of Set 3 | strezhevoy
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | tabialan
# City not found. Skipping...
# Processing Record 32 of Set 3 | stornoway
# Processing Record 33 of Set 3 | ariquemes
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | shihezi
# Processing Record 36 of Set 3 | sur
# Processing Record 37 of Set 3 | ostrovnoy
# Processing Record 38 of Set 3 | ayr
# Processing Record 39 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 3 | maniitsoq
# Processing Record 41 of Set 3 | davila
# Processing Record 42 of Set 3 | dingle
# Processing Record 43 of Set 3 | clyde river
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | urgut
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | arraial do cabo
# Processing Record 48 of Set 3 | chizhou
# Processing Record 49 of Set 3 | goksun
# Processing Record 50 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 4 | preobrazheniye
# Processing Record 2 of Set 4 | isla vista
# Processing Record 3 of Set 4 | markivka
# Processing Record 4 of Set 4 | barrow
# Processing Record 5 of Set 4 | tasiilaq
# Processing Record 6 of Set 4 | sorong
# Processing Record 7 of Set 4 | tongren
# Processing Record 8 of Set 4 | lipno
# Processing Record 9 of Set 4 | dhari
# Processing Record 10 of Set 4 | ancud
# Processing Record 11 of Set 4 | charyshskoye
# Processing Record 12 of Set 4 | cherskiy
# Processing Record 13 of Set 4 | aklavik
# Processing Record 14 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 4 | jambi
# Processing Record 16 of Set 4 | tabou
# Processing Record 17 of Set 4 | arteaga
# Processing Record 18 of Set 4 | rovaniemi
# Processing Record 19 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 20 of Set 4 | zeya
# Processing Record 21 of Set 4 | coxim
# Processing Record 22 of Set 4 | oum hadjer
# Processing Record 23 of Set 4 | grand-santi
# Processing Record 24 of Set 4 | luderitz
# Processing Record 25 of Set 4 | boa vista
# Processing Record 26 of Set 4 | upernavik
# Processing Record 27 of Set 4 | puerto ayora
# Processing Record 28 of Set 4 | chapais
# Processing Record 29 of Set 4 | buenos aires
# Processing Record 30 of Set 4 | cayenne
# Processing Record 31 of Set 4 | graham
# Processing Record 32 of Set 4 | khandyga
# Processing Record 33 of Set 4 | flin flon
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | ilulissat
# Processing Record 36 of Set 4 | mersing
# Processing Record 37 of Set 4 | nouakchott
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | srednekolymsk
# Processing Record 41 of Set 4 | flinders
# Processing Record 42 of Set 4 | vichuga
# Processing Record 43 of Set 4 | kristiinankaupunki
# Processing Record 44 of Set 4 | yar-sale
# Processing Record 45 of Set 4 | lukulu
# Processing Record 46 of Set 4 | aswan
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | praia da vitoria
# Processing Record 49 of Set 4 | mar del plata
# Processing Record 50 of Set 4 | la orilla
# Processing Record 1 of Set 5 | bahia blanca
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | sembakung
# Processing Record 4 of Set 5 | kununurra
# Processing Record 5 of Set 5 | dwarka
# Processing Record 6 of Set 5 | santa rosa
# Processing Record 7 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 5 | feira
# Processing Record 9 of Set 5 | mayen
# Processing Record 10 of Set 5 | mantua
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | umm lajj
# Processing Record 13 of Set 5 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 5 | padang
# Processing Record 15 of Set 5 | champaign
# Processing Record 16 of Set 5 | mehamn
# Processing Record 17 of Set 5 | listvyanka
# Processing Record 18 of Set 5 | genhe
# Processing Record 19 of Set 5 | geraldton
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | ordu
# Processing Record 22 of Set 5 | roanoke rapids
# Processing Record 23 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 24 of Set 5 | caravelas
# Processing Record 25 of Set 5 | brae
# Processing Record 26 of Set 5 | kedougou
# Processing Record 27 of Set 5 | georgetown
# Processing Record 28 of Set 5 | chokurdakh
# Processing Record 29 of Set 5 | santiago del estero
# Processing Record 30 of Set 5 | saskylakh
# Processing Record 31 of Set 5 | kupang
# Processing Record 32 of Set 5 | fort nelson
# Processing Record 33 of Set 5 | qaanaaq
# Processing Record 34 of Set 5 | makakilo city
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | pochutla
# Processing Record 39 of Set 5 | braganca
# Processing Record 40 of Set 5 | tiarei
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | nuevo progreso
# Processing Record 43 of Set 5 | alofi
# Processing Record 44 of Set 5 | khatanga
# Processing Record 45 of Set 5 | san angelo
# Processing Record 46 of Set 5 | shache
# Processing Record 47 of Set 5 | tawang
# Processing Record 48 of Set 5 | takoradi
# Processing Record 49 of Set 5 | belyy yar
# Processing Record 50 of Set 5 | palana
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | hualmay
# Processing Record 3 of Set 6 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 6 | goderich
# Processing Record 5 of Set 6 | les cayes
# Processing Record 6 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 6 | chicama
# Processing Record 8 of Set 6 | alice springs
# Processing Record 9 of Set 6 | eskil
# Processing Record 10 of Set 6 | yakeshi
# Processing Record 11 of Set 6 | nata
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 6 | olinda
# Processing Record 14 of Set 6 | dudinka
# Processing Record 15 of Set 6 | gazanjyk
# Processing Record 16 of Set 6 | zhuozhou
# City not found. Skipping...
# Processing Record 17 of Set 6 | chuy
# Processing Record 18 of Set 6 | necochea
# Processing Record 19 of Set 6 | khor
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 6 | anzoategui
# Processing Record 23 of Set 6 | kruisfontein
# Processing Record 24 of Set 6 | meadow lake
# Processing Record 25 of Set 6 | ixtapa
# Processing Record 26 of Set 6 | jumla
# Processing Record 27 of Set 6 | west odessa
# Processing Record 28 of Set 6 | smidovich
# Processing Record 29 of Set 6 | lebu
# Processing Record 30 of Set 6 | uaua
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | iranshahr
# Processing Record 33 of Set 6 | saint-francois
# Processing Record 34 of Set 6 | antofagasta
# Processing Record 35 of Set 6 | altay
# Processing Record 36 of Set 6 | clarence town
# Processing Record 37 of Set 6 | ornskoldsvik
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | jacareacanga
# Processing Record 40 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 6 | mazatlan
# Processing Record 42 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 6 | dikson
# Processing Record 44 of Set 6 | turukhansk
# Processing Record 45 of Set 6 | esperance
# Processing Record 46 of Set 6 | goundam
# Processing Record 47 of Set 6 | tommot
# Processing Record 48 of Set 6 | las palmas
# Processing Record 49 of Set 6 | jalingo
# Processing Record 50 of Set 6 | kudahuvadhoo
# Processing Record 1 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 7 | melfi
# Processing Record 3 of Set 7 | svetlyy
# Processing Record 4 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 7 | constitucion
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | ambulu
# Processing Record 8 of Set 7 | shakiso
# Processing Record 9 of Set 7 | vanimo
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | zadar
# Processing Record 12 of Set 7 | macedo de cavaleiros
# Processing Record 13 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 7 | gwadar
# Processing Record 15 of Set 7 | byron bay
# Processing Record 16 of Set 7 | noumea
# Processing Record 17 of Set 7 | oistins
# Processing Record 18 of Set 7 | oranjestad
# Processing Record 19 of Set 7 | itarema
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | ardistan
# City not found. Skipping...
# Processing Record 22 of Set 7 | karratha
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | tierra blanca
# Processing Record 25 of Set 7 | malandag
# Processing Record 26 of Set 7 | mayo
# Processing Record 27 of Set 7 | saint george
# Processing Record 28 of Set 7 | ziyang
# Processing Record 29 of Set 7 | caraballeda
# Processing Record 30 of Set 7 | olafsvik
# Processing Record 31 of Set 7 | asvestokhorion
# City not found. Skipping...
# Processing Record 32 of Set 7 | novosokolniki
# Processing Record 33 of Set 7 | kilindoni
# Processing Record 34 of Set 7 | huambo
# Processing Record 35 of Set 7 | jatai
# Processing Record 36 of Set 7 | port macquarie
# Processing Record 37 of Set 7 | ahipara
# Processing Record 38 of Set 7 | phan thiet
# Processing Record 39 of Set 7 | yulara
# Processing Record 40 of Set 7 | winnemucca
# Processing Record 41 of Set 7 | olutanga
# Processing Record 42 of Set 7 | balabag
# Processing Record 43 of Set 7 | coahuayana
# Processing Record 44 of Set 7 | kirakira
# Processing Record 45 of Set 7 | monterey
# Processing Record 46 of Set 7 | tulun
# Processing Record 47 of Set 7 | acarau
# Processing Record 48 of Set 7 | kiruna
# Processing Record 49 of Set 7 | kyzyl-suu
# Processing Record 50 of Set 7 | inhambane
# Processing Record 1 of Set 8 | fortuna
# Processing Record 2 of Set 8 | sandy springs
# Processing Record 3 of Set 8 | dongsheng
# Processing Record 4 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 8 | marystown
# Processing Record 6 of Set 8 | mandera
# Processing Record 7 of Set 8 | narsaq
# Processing Record 8 of Set 8 | beringovskiy
# Processing Record 9 of Set 8 | salinopolis
# Processing Record 10 of Set 8 | iwaki
# Processing Record 11 of Set 8 | raudeberg
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | tazovskiy
# Processing Record 14 of Set 8 | margate
# Processing Record 15 of Set 8 | siswa bazar
# Processing Record 16 of Set 8 | dolores
# Processing Record 17 of Set 8 | kutiyana
# Processing Record 18 of Set 8 | hambantota
# Processing Record 19 of Set 8 | sirok
# Processing Record 20 of Set 8 | kargopol
# Processing Record 21 of Set 8 | san roque
# Processing Record 22 of Set 8 | shingu
# Processing Record 23 of Set 8 | nuuk
# Processing Record 24 of Set 8 | anuchino
# Processing Record 25 of Set 8 | mashhad
# Processing Record 26 of Set 8 | jinxiang
# Processing Record 27 of Set 8 | mandan
# Processing Record 28 of Set 8 | grimari
# City not found. Skipping...
# Processing Record 29 of Set 8 | oulainen
# Processing Record 30 of Set 8 | san cristobal
# Processing Record 31 of Set 8 | myitkyina
# Processing Record 32 of Set 8 | opuwo
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | bilma
# Processing Record 35 of Set 8 | egvekinot
# Processing Record 36 of Set 8 | launceston
# Processing Record 37 of Set 8 | ganzhou
# Processing Record 38 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 8 | kawalu
# Processing Record 40 of Set 8 | dunmore town
# Processing Record 41 of Set 8 | tchibanga
# Processing Record 42 of Set 8 | villamontes
# Processing Record 43 of Set 8 | faya
# Processing Record 44 of Set 8 | udachnyy
# Processing Record 45 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 46 of Set 8 | dodge city
# Processing Record 47 of Set 8 | bathsheba
# Processing Record 48 of Set 8 | dalby
# Processing Record 49 of Set 8 | azul
# Processing Record 50 of Set 8 | rovnoye
# Processing Record 1 of Set 9 | izalco
# Processing Record 2 of Set 9 | andrushivka
# Processing Record 3 of Set 9 | vaitape
# Processing Record 4 of Set 9 | tuatapere
# Processing Record 5 of Set 9 | sao filipe
# Processing Record 6 of Set 9 | varhaug
# Processing Record 7 of Set 9 | rock sound
# Processing Record 8 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 9 | vila
# Processing Record 10 of Set 9 | kizhinga
# Processing Record 11 of Set 9 | svetlogorsk
# Processing Record 12 of Set 9 | klaksvik
# Processing Record 13 of Set 9 | nabire
# Processing Record 14 of Set 9 | bongandanga
# Processing Record 15 of Set 9 | tomatlan
# Processing Record 16 of Set 9 | praya
# Processing Record 17 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 9 | port shepstone
# Processing Record 19 of Set 9 | wasilla
# Processing Record 20 of Set 9 | areka
# Processing Record 21 of Set 9 | namatanai
# Processing Record 22 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 9 | san lorenzo
# Processing Record 24 of Set 9 | korcula
# Processing Record 25 of Set 9 | lethem
# Processing Record 26 of Set 9 | yeppoon
# Processing Record 27 of Set 9 | carikar
# City not found. Skipping...
# Processing Record 28 of Set 9 | sitka
# Processing Record 29 of Set 9 | arkalokhorion
# City not found. Skipping...
# Processing Record 30 of Set 9 | ijaki
# City not found. Skipping...
# Processing Record 31 of Set 9 | kirkwall
# Processing Record 32 of Set 9 | leh
# Processing Record 33 of Set 9 | waddan
# Processing Record 34 of Set 9 | chumikan
# Processing Record 35 of Set 9 | tiznit
# Processing Record 36 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 37 of Set 9 | chernyshevskiy
# Processing Record 38 of Set 9 | catacocha
# Processing Record 39 of Set 9 | esso
# Processing Record 40 of Set 9 | ilhabela
# Processing Record 41 of Set 9 | puerto ayacucho
# Processing Record 42 of Set 9 | adre
# Processing Record 43 of Set 9 | baykit
# Processing Record 44 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 9 | hailar
# Processing Record 46 of Set 9 | perevoz
# Processing Record 47 of Set 9 | zhigansk
# Processing Record 48 of Set 9 | moerai
# Processing Record 49 of Set 9 | lardos
# Processing Record 50 of Set 9 | san javier
# Processing Record 1 of Set 10 | port-gentil
# Processing Record 2 of Set 10 | liuli
# Processing Record 3 of Set 10 | oyama
# Processing Record 4 of Set 10 | ploemeur
# Processing Record 5 of Set 10 | kizilskoye
# Processing Record 6 of Set 10 | sacalaseni
# City not found. Skipping...
# Processing Record 7 of Set 10 | saint-augustin
# Processing Record 8 of Set 10 | umm kaddadah
# Processing Record 9 of Set 10 | ozernovskiy
# Processing Record 10 of Set 10 | mon
# Processing Record 11 of Set 10 | iqaluit
# Processing Record 12 of Set 10 | glazov
# Processing Record 13 of Set 10 | hasaki
# Processing Record 14 of Set 10 | lincoln
# Processing Record 15 of Set 10 | santa maria
# Processing Record 16 of Set 10 | pau
# Processing Record 17 of Set 10 | tandalti
# Processing Record 18 of Set 10 | magalia
# Processing Record 19 of Set 10 | dubovskoye
# Processing Record 20 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 21 of Set 10 | atenas
# Processing Record 22 of Set 10 | ukiah
# Processing Record 23 of Set 10 | beloha
# Processing Record 24 of Set 10 | westport
# Processing Record 25 of Set 10 | nadym
# Processing Record 26 of Set 10 | yerbogachen
# Processing Record 27 of Set 10 | shellbrook
# Processing Record 28 of Set 10 | amposta
# Processing Record 29 of Set 10 | tyubuk
# Processing Record 30 of Set 10 | ballarat
# Processing Record 31 of Set 10 | richards bay
# Processing Record 32 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 10 | gamba
# Processing Record 34 of Set 10 | thunder bay
# Processing Record 35 of Set 10 | whitehorse
# Processing Record 36 of Set 10 | dumas
# Processing Record 37 of Set 10 | gympie
# Processing Record 38 of Set 10 | aitape
# Processing Record 39 of Set 10 | khasan
# Processing Record 40 of Set 10 | presidencia roque saenz pena
# Processing Record 41 of Set 10 | chinsali
# Processing Record 42 of Set 10 | mount gambier
# Processing Record 43 of Set 10 | trapani
# Processing Record 44 of Set 10 | nyurba
# Processing Record 45 of Set 10 | atar
# Processing Record 46 of Set 10 | merauke
# Processing Record 47 of Set 10 | manutuke
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | marathopolis
# City not found. Skipping...
# Processing Record 50 of Set 10 | miri
# Processing Record 1 of Set 11 | abay
# Processing Record 2 of Set 11 | tonstad
# Processing Record 3 of Set 11 | tahta
# Processing Record 4 of Set 11 | general cepeda
# Processing Record 5 of Set 11 | kamaishi
# Processing Record 6 of Set 11 | sirpur
# Processing Record 7 of Set 11 | gat
# Processing Record 8 of Set 11 | quatre cocos
# Processing Record 9 of Set 11 | codrington
# Processing Record 10 of Set 11 | akdepe
# Processing Record 11 of Set 11 | viedma
# Processing Record 12 of Set 11 | nanakuli
# Processing Record 13 of Set 11 | labuhan
# Processing Record 14 of Set 11 | victor harbor
# Processing Record 15 of Set 11 | san vicente de canete
# Processing Record 16 of Set 11 | isangel
# Processing Record 17 of Set 11 | prieska
# Processing Record 18 of Set 11 | ust-kuyga
# Processing Record 19 of Set 11 | bushehr
# Processing Record 20 of Set 11 | ostersund
# Processing Record 21 of Set 11 | qaqortoq
# Processing Record 22 of Set 11 | port hedland
# Processing Record 23 of Set 11 | duz
# City not found. Skipping...
# Processing Record 24 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 11 | nioki
# Processing Record 26 of Set 11 | faanui
# Processing Record 27 of Set 11 | berdigestyakh
# Processing Record 28 of Set 11 | pahrump
# Processing Record 29 of Set 11 | comodoro rivadavia
# Processing Record 30 of Set 11 | shimoda
# Processing Record 31 of Set 11 | adrar
# Processing Record 32 of Set 11 | batticaloa
# Processing Record 33 of Set 11 | bonnyville
# Processing Record 34 of Set 11 | bud
# Processing Record 35 of Set 11 | puerto rondon
# Processing Record 36 of Set 11 | jining
# Processing Record 37 of Set 11 | lasa
# Processing Record 38 of Set 11 | mackenzie
# Processing Record 39 of Set 11 | mogadishu
# Processing Record 40 of Set 11 | flers
# Processing Record 41 of Set 11 | rumuruti
# Processing Record 42 of Set 11 | wagga wagga
# Processing Record 43 of Set 11 | voznesenye
# Processing Record 44 of Set 11 | kenai
# Processing Record 45 of Set 11 | amalapuram
# Processing Record 46 of Set 11 | arinos
# Processing Record 47 of Set 11 | bundibugyo
# Processing Record 48 of Set 11 | pyaozerskiy
# Processing Record 49 of Set 11 | ayagoz
# Processing Record 50 of Set 11 | ekhabi
# Processing Record 1 of Set 12 | kabare
# Processing Record 2 of Set 12 | okahandja
# Processing Record 3 of Set 12 | husavik
# Processing Record 4 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 5 of Set 12 | wajima
# Processing Record 6 of Set 12 | sant julia de loria
# Processing Record 7 of Set 12 | sao joao da barra
# Processing Record 8 of Set 12 | uyuni
# Processing Record 9 of Set 12 | elizabethtown
# Processing Record 10 of Set 12 | mozarlandia
# Processing Record 11 of Set 12 | riaba
# City not found. Skipping...
# Processing Record 12 of Set 12 | lavrentiya
# Processing Record 13 of Set 12 | balabac
# Processing Record 14 of Set 12 | pokrovsk
# Processing Record 15 of Set 12 | jamame
# Processing Record 16 of Set 12 | nelson bay
# Processing Record 17 of Set 12 | chilliwack
# Processing Record 18 of Set 12 | oliveira dos brejinhos
# Processing Record 19 of Set 12 | solnechnyy
# Processing Record 20 of Set 12 | ceyhan
# Processing Record 21 of Set 12 | minas novas
# Processing Record 22 of Set 12 | demirci
# Processing Record 23 of Set 12 | huarmey
# Processing Record 24 of Set 12 | raga
# Processing Record 25 of Set 12 | valdivia
# Processing Record 26 of Set 12 | boueni
# Processing Record 27 of Set 12 | misratah
# Processing Record 28 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 12 | hajnowka
# Processing Record 30 of Set 12 | veseloyarsk
# Processing Record 31 of Set 12 | pangai
# Processing Record 32 of Set 12 | minnedosa
# Processing Record 33 of Set 12 | skibotn
# Processing Record 34 of Set 12 | tilichiki
# Processing Record 35 of Set 12 | pangnirtung
# Processing Record 36 of Set 12 | zhangzhou
# Processing Record 37 of Set 12 | caruray
# Processing Record 38 of Set 12 | utete
# Processing Record 39 of Set 12 | abu dhabi
# Processing Record 40 of Set 12 | moussoro
# Processing Record 41 of Set 12 | nouadhibou
# Processing Record 42 of Set 12 | rorvik
# Processing Record 43 of Set 12 | ambon
# Processing Record 44 of Set 12 | masallatah
# Processing Record 45 of Set 12 | nola
# Processing Record 46 of Set 12 | neuquen
# Processing Record 47 of Set 12 | yuzhno-kurilsk
# Processing Record 48 of Set 12 | tacoronte
# Processing Record 49 of Set 12 | nome
# Processing Record 50 of Set 12 | bejuco
# Processing Record 1 of Set 13 | irricana
# Processing Record 2 of Set 13 | havoysund
# Processing Record 3 of Set 13 | lynge
# Processing Record 4 of Set 13 | sal rei
# Processing Record 5 of Set 13 | bubaque
# Processing Record 6 of Set 13 | coquimbo
# Processing Record 7 of Set 13 | antalaha
# Processing Record 8 of Set 13 | ust-kut
# Processing Record 9 of Set 13 | sangueya
# Processing Record 10 of Set 13 | coihaique
# Processing Record 11 of Set 13 | oranjemund
# Processing Record 12 of Set 13 | osoyoos
# Processing Record 13 of Set 13 | cosenza
# Processing Record 14 of Set 13 | touros
# Processing Record 15 of Set 13 | catuday
# Processing Record 16 of Set 13 | payyannur
# Processing Record 17 of Set 13 | bharatpur
# Processing Record 18 of Set 13 | luhyny
# Processing Record 19 of Set 13 | roald
# Processing Record 20 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 21 of Set 13 | te anau
# Processing Record 22 of Set 13 | bandarbeyla
# Processing Record 23 of Set 13 | havre-saint-pierre
# Processing Record 24 of Set 13 | chimbote
# Processing Record 25 of Set 13 | puerto del rosario
# Processing Record 26 of Set 13 | shanhetun
# Processing Record 27 of Set 13 | nagua
# Processing Record 28 of Set 13 | riviere-au-renard
# Processing Record 29 of Set 13 | seymchan
# Processing Record 30 of Set 13 | turinskaya sloboda
# Processing Record 31 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 13 | uchiza
# Processing Record 34 of Set 13 | verkhoturye
# Processing Record 35 of Set 13 | oruro
# Processing Record 36 of Set 13 | gondanglegi
# Processing Record 37 of Set 13 | arcata
# Processing Record 38 of Set 13 | sao jose da coroa grande
# Processing Record 39 of Set 13 | tabory
# Processing Record 40 of Set 13 | arlit
# Processing Record 41 of Set 13 | lanzhou
# Processing Record 42 of Set 13 | luganville
# Processing Record 43 of Set 13 | hofn
# Processing Record 44 of Set 13 | port hawkesbury
# Processing Record 45 of Set 13 | natal
# Processing Record 46 of Set 13 | bratsk
# Processing Record 47 of Set 13 | bouar
# Processing Record 48 of Set 13 | pudozh
# Processing Record 49 of Set 13 | le vauclin
# Processing Record 50 of Set 13 | bonthe
# Processing Record 1 of Set 14 | rwamagana
# Processing Record 2 of Set 14 | outjo
# Processing Record 3 of Set 14 | san andres
# Processing Record 4 of Set 14 | puerto leguizamo
# Processing Record 5 of Set 14 | lazaro cardenas
# Processing Record 6 of Set 14 | kuznechnoye
# Processing Record 7 of Set 14 | juneau
# Processing Record 8 of Set 14 | panguna
# Processing Record 9 of Set 14 | bonavista
# Processing Record 10 of Set 14 | yima
# Processing Record 11 of Set 14 | lujan
# Processing Record 12 of Set 14 | wajir
# Processing Record 13 of Set 14 | kalofer
# Processing Record 14 of Set 14 | sandakan
# Processing Record 15 of Set 14 | buchanan
# Processing Record 16 of Set 14 | ponta delgada
# Processing Record 17 of Set 14 | arari
# Processing Record 18 of Set 14 | amot
# Processing Record 19 of Set 14 | paysandu
# Processing Record 20 of Set 14 | ilebo
# Processing Record 21 of Set 14 | nizhniy kuranakh
# Processing Record 22 of Set 14 | paso de los toros
# Processing Record 23 of Set 14 | eureka
# Processing Record 24 of Set 14 | zhanakorgan
# Processing Record 25 of Set 14 | bardiyah
# Processing Record 26 of Set 14 | miyako
# Processing Record 27 of Set 14 | nsawam
# Processing Record 28 of Set 14 | aranos
# Processing Record 29 of Set 14 | soc trang
# Processing Record 30 of Set 14 | gambela
# Processing Record 31 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 14 | kang
# Processing Record 33 of Set 14 | asmar
# Processing Record 34 of Set 14 | urdoma
# Processing Record 35 of Set 14 | saint-georges
# Processing Record 36 of Set 14 | arman
# Processing Record 37 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 38 of Set 14 | tokur
# Processing Record 39 of Set 14 | los llanos de aridane
# Processing Record 40 of Set 14 | poltavka
# Processing Record 41 of Set 14 | rocha
# Processing Record 42 of Set 14 | clovis
# Processing Record 43 of Set 14 | vilyuysk
# Processing Record 44 of Set 14 | espanola
# Processing Record 45 of Set 14 | mahaicony
# City not found. Skipping...
# Processing Record 46 of Set 14 | wattegama
# Processing Record 47 of Set 14 | henties bay
# Processing Record 48 of Set 14 | abapo
# Processing Record 49 of Set 14 | roebourne
# Processing Record 50 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 15 | guerrero negro
# Processing Record 2 of Set 15 | sungaipenuh
# Processing Record 3 of Set 15 | gari
# Processing Record 4 of Set 15 | hays
# Processing Record 5 of Set 15 | port blair
# Processing Record 6 of Set 15 | saint-gabriel
# Processing Record 7 of Set 15 | mae hong son
# Processing Record 8 of Set 15 | gonbad-e qabus
# Processing Record 9 of Set 15 | placido de castro
# Processing Record 10 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 15 | rio grande
# Processing Record 12 of Set 15 | berlevag
# Processing Record 13 of Set 15 | sibenik
# Processing Record 14 of Set 15 | trincomalee
# Processing Record 15 of Set 15 | lutkun
# Processing Record 16 of Set 15 | bukavu
# Processing Record 17 of Set 15 | san quintin
# Processing Record 18 of Set 15 | bentiu
# Processing Record 19 of Set 15 | kaitangata
# Processing Record 20 of Set 15 | komsomolskiy
# Processing Record 21 of Set 15 | sambava
# Processing Record 22 of Set 15 | kopavogur
# Processing Record 23 of Set 15 | ichalkaranji
# Processing Record 24 of Set 15 | tokonou
# Processing Record 25 of Set 15 | sangar
# Processing Record 26 of Set 15 | luan
# Processing Record 27 of Set 15 | cap malheureux
# Processing Record 28 of Set 15 | buraydah
# Processing Record 29 of Set 15 | aksu
# Processing Record 30 of Set 15 | salgueiro
# Processing Record 31 of Set 15 | nago
# Processing Record 32 of Set 15 | rawson
# Processing Record 33 of Set 15 | bomet
# Processing Record 34 of Set 15 | spirit river
# Processing Record 35 of Set 15 | ojinaga
# Processing Record 36 of Set 15 | marienburg
# Processing Record 37 of Set 15 | severnyy-kospashskiy
# Processing Record 38 of Set 15 | narragansett
# Processing Record 39 of Set 15 | nortelandia
# Processing Record 40 of Set 15 | valdepenas
# Processing Record 41 of Set 15 | pushkino
# Processing Record 42 of Set 15 | la ferte-bernard
# Processing Record 43 of Set 15 | nichinan
# Processing Record 44 of Set 15 | guadalupe y calvo
# Processing Record 45 of Set 15 | huilong
# Processing Record 46 of Set 15 | tevriz
# Processing Record 47 of Set 15 | guanhaes
# Processing Record 48 of Set 15 | plettenberg bay
# Processing Record 49 of Set 15 | dunedin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#        City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   rikitea -23.1203 -134.9692     73.72        79         100        7.36
# 1   ushuaia -54.8000  -68.3000     38.86        93         100       23.02
# 2   mataura -46.1927  168.8643     47.48        98          54        3.11
# 3     airai  -8.9266  125.4092     61.86        93          97        0.74
# 4    albany  42.6001  -73.9662     58.64        48           0        1.79
# 5   ternate   0.8000  127.4000     81.52        78          91        1.61
# 6   kahului  20.8947 -156.4700     78.84        75          20        6.91
# 7  ushibuka  32.1906  130.0228     61.66        71           2        9.71
# 8    avarua -21.2078 -159.7750     73.45        73          75        6.91
# 9    tandil -37.3217  -59.1332     66.69        38          31       15.08
#
#   Country Current Description
# 0      PF          light rain
# 1      AR          light rain
# 2      NZ       broken clouds
# 3      TL     overcast clouds
# 4      US           clear sky
# 5      ID     overcast clouds
# 6      US          few clouds
# 7      JP           clear sky
# 8      CK       broken clouds
# 9      AR    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
city_data_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_order]

# Display sample data
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   rikitea      PF -23.1203 -134.9692     73.72        79         100
# 1   ushuaia      AR -54.8000  -68.3000     38.86        93         100
# 2   mataura      NZ -46.1927  168.8643     47.48        98          54
# 3     airai      TL  -8.9266  125.4092     61.86        93          97
# 4    albany      US  42.6001  -73.9662     58.64        48           0
# 5   ternate      ID   0.8000  127.4000     81.52        78          91
# 6   kahului      US  20.8947 -156.4700     78.84        75          20
# 7  ushibuka      JP  32.1906  130.0228     61.66        71           2
# 8    avarua      CK -21.2078 -159.7750     73.45        73          75
# 9    tandil      AR -37.3217  -59.1332     66.69        38          31
#
#    Wind Speed Current Description
# 0        7.36          light rain
# 1       23.02          light rain
# 2        3.11       broken clouds
# 3        0.74     overcast clouds
# 4        1.79           clear sky
# 5        1.61     overcast clouds
# 6        6.91          few clouds
# 7        9.71           clear sky
# 8        6.91       broken clouds
# 9       15.08    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
